# %%
import requests
import json
import pprint
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
response=requests.get('https://tcgbusfs.blob.core.windows.net/blobyoubike/YouBikeTP.json')
content = response.content
json_tree = json.loads(content)

# %%
df=pd.DataFrame(json_tree)

# %%
df=pd.read_csv('youbike-taipei.csv',sep=';')
# Out:
#    num  retCode  sno  tot  sbi          mday        lat         lng  \
# 0    1        1    1  180   32  2.020100e+13  25.040858  121.567904
# 1    2        1    2   48   11  2.020100e+13  25.041254  121.557420
# 2    3        1    3   40   19  2.020100e+13  25.037797  121.565169
# 3    4        1    4   60   36  2.020100e+13  25.036036  121.562325
# 4    5        1    5   60   13  2.020100e+13  25.036564  121.568664
#
#           sarean                                        snaen
# 0    Xinyi Dist.      MRT Taipei City Hall Stataion(Exit 3)-2
# 1     Daan Dist.    MRT S.Y.S Memorial Hall Stataion(Exit 2.)
# 2    Xinyi Dist.                             Taipei City Hall
# 3    Xinyi Dist.                               Citizen Square
# 4    Xinyi Dist.                       Xingya Jr. High School

# %%
import folium

leftRatio=df['sbi']/df['tot']*100
df['lat']=pd.to_numeric(df['lat'])
df['lng']=pd.to_numeric(df['lng'])

loc=df[['lat','lng']].values.tolist()
mapit = folium.Map( location=loc[6], zoom_start=6 )
for point in range(0, len(loc)):
    folium.Marker(loc[point], popup=[leftRatio[point],df['snaen'][point],df['sarean'][point]]).add_to(mapit)
mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
